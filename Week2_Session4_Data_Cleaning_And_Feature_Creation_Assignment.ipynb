# %% [markdown]
# <a href="https://colab.research.google.com/github/QUADRIABUBAKAR/ACCESS-Data-science-assignment/blob/main/Week2_Session4_Data_Cleaning_And_Feature_Creation_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
r

# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')
sales_data = pd.read_csv('/content/drive/MyDrive/Warehouse_and_Retail_Sales.csv')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
sales_data.head()
# Out:
#    YEAR  MONTH                           SUPPLIER ITEM CODE  \
# 0  2020      1  REPUBLIC NATIONAL DISTRIBUTING CO    100009
# 1  2020      1                          PWSWN INC    100024
# 2  2020      1            RELIABLE CHURCHILL LLLP      1001
# 3  2020      1          LANTERNA DISTRIBUTORS INC    100145
# 4  2020      1               DIONYSOS IMPORTS INC    100293
#
#                       ITEM DESCRIPTION ITEM TYPE  RETAIL SALES  \
# 0                  BOOTLEG RED - 750ML      WINE          0.00
# 1            MOMENT DE PLAISIR - 750ML      WINE          0.00
# 2  S SMITH ORGANIC PEAR CIDER - 18.7OZ      BEER          0.00
# 3        SCHLINK HAUS KABINETT - 750ML      WINE          0.00
# 4       SANTORINI GAVALA WHITE - 750ML      WINE          0.82
#
#    RETAIL TRANSFERS  WAREHOUSE SALES
# 0               0.0              2.0
# 1               1.0              4.0
# 2               0.0              1.0
# 3               0.0              1.0
# ...

# %%
sales_data.isna().sum()
# Out:
# YEAR                  0
# MONTH                 0
# SUPPLIER            167
# ITEM CODE             0
# ITEM DESCRIPTION      0
# ITEM TYPE             1
# RETAIL SALES          3
# RETAIL TRANSFERS      0
# WAREHOUSE SALES       0
# dtype: int64

# %%
sales_data.shape
# Out:
# (307645, 9)

# %%
for column in sales_data.columns:
    unique_values = sales_data[column].unique()
    print(f"Column '{column}':")
    print(f"  Number of unique values: {len(unique_values)}")
    if len(unique_values) < 20:
        print(f"  Unique values: {unique_values}\n")
    else:
        print("\n")
# Out:
# Column 'YEAR':
#   Number of unique values: 4
#   Unique values: [2020 2017 2018 2019]
#
# Column 'MONTH':
#   Number of unique values: 12
#   Unique values: [ 1  7  3  9  6  8 12 10 11  2  4  5]
#
# Column 'SUPPLIER':
#   Number of unique values: 397
#
#
# Column 'ITEM CODE':
#   Number of unique values: 34056
#
#
# Column 'ITEM DESCRIPTION':
#   Number of unique values: 34822
#
#
# Column 'ITEM TYPE':
#   Number of unique values: 9
#   Unique values: ['WINE' 'BEER' 'LIQUOR' 'STR_SUPPLIES' 'KEGS' 'REF' 'DUNNAGE'
#  'NON-ALCOHOL' nan]
#
# Column 'RETAIL SALES':
#   Number of unique values: 10675
#
#
# Column 'RETAIL TRANSFERS':
#   Number of unique values: 2504
#
#
# Column 'WAREHOUSE SALES':
#   Number of unique values: 4895

# %%
# Decision: Drop this column, IT IS NOT Needed for analysis
sales_data_clean = sales_data.drop(columns=['ITEM DESCRIPTION'])

# %%
sales_data_clean.head()
# Out:
#    YEAR  MONTH                           SUPPLIER ITEM CODE ITEM TYPE  \
# 0  2020      1  REPUBLIC NATIONAL DISTRIBUTING CO    100009      WINE
# 1  2020      1                          PWSWN INC    100024      WINE
# 2  2020      1            RELIABLE CHURCHILL LLLP      1001      BEER
# 3  2020      1          LANTERNA DISTRIBUTORS INC    100145      WINE
# 4  2020      1               DIONYSOS IMPORTS INC    100293      WINE
#
#    RETAIL SALES  RETAIL TRANSFERS  WAREHOUSE SALES
# 0          0.00               0.0              2.0
# 1          0.00               1.0              4.0
# 2          0.00               0.0              1.0
# 3          0.00               0.0              1.0
# 4          0.82               0.0              0.0
