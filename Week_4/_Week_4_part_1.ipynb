# %% [markdown]
# <a href="https://colab.research.google.com/github/QUADRIABUBAKAR/ACCESS-Data-science-assignment/blob/main/Week_4/_Week_4_part_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###Part 1:
#  Apply preprocessing ideas to the dataset "Warehouse and Retail Sales Montgomery County"

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# LOAD THE CLEANED DATASET
cleaned_data = pd.read_csv('/content/drive/MyDrive/cleaned_data.csv')

# %% [markdown]
# Other categorical Variables has too many unique columns
# that One Hot Encoder will create man columns so it is better to use more advanced encoding methods or drop the columns.
#
# After conducting the univariate and bivariate analyses, the numerical features that would most likely benefit from scaling are:
#
# RETAIL SALES
#
# RETAIL TRANSFERS:
#
# WAREHOUSE SALES:
